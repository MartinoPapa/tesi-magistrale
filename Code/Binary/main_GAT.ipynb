# %%
import sys
sys.path.append('..')

# %%
from data_preparation import DataPreparation
from loader.dataset_factory import DatasetFactory
from model.gagnn import GAGNN
from model.loss import GAGNNLoss
from sklearn.metrics import f1_score
from torch_geometric.data import Data
from torch_geometric.loader import NeighborLoader
from utils import Evaluator
import itertools
import json
import numpy as np
import os
import pandas as pd
import torch

# %%
import random
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True
set_seed(42)
torch.set_float32_matmul_precision('medium')

# %%
# =============================================================================
# GNN Configuration
# =============================================================================
gnn_type = 'gat'
save_to_folder = 'saved_models_GAT'

# =============================================================================
# Model Architecture — Grid Search Lists
# =============================================================================
hidden_dims = [64, 128]
out_dims = [64, 128]
num_layers_list = [2, 3]
betas = [0.44]
mlp_hidden_dims = [128]
nn_t_hidden_dims = [128, 256]

heads_list = [3, 5]

# =============================================================================
# Loss Weights
# =============================================================================
c1_list = [0.65, 0.75, 0.85]
c2_list = [0.65, 0.75, 0.85]
c3_list = [0.9, 1.0, 1.1]
laundry_weights = [1.0, 2.0, 3.0]

# =============================================================================
# Training & Cross-Validation
# =============================================================================
learning_rates = [0.0001]
max_norm_clipping = [5.0]

epochs_model_selection = 3000
epochs_train = 6000

minibatches = True
batch_size = 1024
num_neighbors = [10, 10]

patience_selection = 100
moving_average_epochs = 5
patience_training = 200

print_every = 20
save_every = 100

# =============================================================================
# Class Imbalance
# =============================================================================
downsample = True

# =============================================================================
# Temporal Train / Validation / Test Split
# =============================================================================
date_time_1 = '2022-09-07 14:55:00'
date_time_2 = '2022-09-08 16:12:00'

# %% [markdown]
# import IBM AMLSim

# %%
from loader.dataset_factory import DatasetFactory

# Inizializza il loader specificando il nome canonico del dataset
loader = DatasetFactory.get_loader(
    "ibm_amlsim", 
    engine="pyarrow", 
    dtype_backend="pyarrow", 
    nrows=None
)
# pyarrow is faster and uses less memory, it takes NumPy place

# Carica i dati in memoria (file delle transazioni e, se presente, degli account)
loader.load()

# Stampa un riepilogo conciso del dataset caricato per verificare che sia tutto ok
loader.summary()
# Out:
# Loading IBM AMLSim transactions from: c:\Users\marti\OneDrive\Desktop\Tesi v2\Code\Binary\..\loader\..\data\ibm_amlsim\HI-Small_Trans.csv
#   Loaded 5,078,345 rows.
# Loading IBM AMLSim accounts from: c:\Users\marti\OneDrive\Desktop\Tesi v2\Code\Binary\..\loader\..\data\ibm_amlsim\HI-Small_accounts.csv
#   Loaded 518,581 account records.
# ============================================================
#   Dataset : IBMAMLSimLoader
#   Rows    : 5,078,345
#   Columns : 11
#   Fraud   : 5,177  (0.1019 %)
# ============================================================

# %%
loader.print_features()
# Out:
# Column               Type         Description
# --------------------------------------------------------------------------------
# Timestamp            string[pyarrow] Date and time of the transaction
# From Bank            int64[pyarrow] Numeric identifier of the originating bank  (e.g. [1, 10, 12, 3208, 3209])
# Account              string[pyarrow] Hexadecimal ID of the sender account (node)
# To Bank              int64[pyarrow] Numeric identifier of the receiving bank  (e.g. [1, 10, 12, 2439, 3209])
# Account.1            string[pyarrow] Hexadecimal ID of the receiver account (node)
# Amount Received      double[pyarrow] Transaction amount in the receiving currency
# Receiving Currency   string[pyarrow] Currency received by the destination account  (e.g. ['US Dollar', 'Bitcoin', 'Euro', 'Australian Dollar', 'Yuan', 'Rupee'])
# Amount Paid          double[pyarrow] Transaction amount in the paying currency
# Payment Currency     string[pyarrow] Currency used by the sender  (e.g. ['US Dollar', 'Bitcoin', 'Euro', 'Australian Dollar', 'Yuan', 'Rupee'])
# Payment Format       string[pyarrow] Payment method / instrument  (e.g. ['Reinvestment', 'Cheque', 'Credit Card', 'ACH', 'Cash', 'Wire', 'Bitcoin'])
# Is Laundering        int64        Ground-truth fraud label: 1 = money-laundering, 0 = normal  (e.g. [0, 1])
# Bank Name            str          Full name of the bank (from accounts file)  (e.g. ['Portugal Bank #4507', 'Canada Bank #27', 'UK Bank #33', 'Germany Bank #4815', 'National Bank of Harrisburg', 'Spain Bank #439'])
# Bank ID              int64        Numeric bank identifier (from accounts file)
# Account Number       str          Hexadecimal account ID — matches Account / Account.1
# Entity ID            str          Unique entity identifier (from accounts file)
# Entity Name          str          Human-readable entity name (e.g. Corporation #12345)  (e.g. ['Sole Proprietorship #50438', 'Corporation #33520', 'Partnership #35397', 'Corporation #48813'])

# %% [markdown]
# Data preparation

# %%
from data_preparation import DataPreparation
import pandas as pd

# Otteniamo il dataframe raw delle transazioni dal nostro loader
transactions_df = loader.get_transactions()

# Calcoliamo la maschera di training per evitare data leakage nello scaler
ts_raw = pd.to_datetime(transactions_df['Timestamp'])
thresh_val = pd.to_datetime(date_time_1)
train_mask_raw = ts_raw < thresh_val

# Inizializziamo la classe scegliendo il robust scaler
data_prep = DataPreparation(scaler_type='robust')

# 1. Calcoliamo le feature standardizzate per le transazioni (gli archi E)
edges_features_df = data_prep.fit_transform_edges(transactions_df, train_mask=train_mask_raw)

# 2. Aggreghiamo le transazioni per ricavare l'embedding iniziale dei nodi (V)
nodes_features_df = data_prep.get_node_features(edges_features_df, train_mask=train_mask_raw)

print(f"Dimensione feature archi: {edges_features_df.shape}")
print(f"Dimensione feature nodi: {nodes_features_df.shape}")

# Stampa bilanciamento classi (Nodi e Archi)
print("\n--- Bilanciamento Dataset ---")
num_fraud_nodes = (nodes_features_df["Is Laundering"] > 0).sum()
num_legit_nodes = len(nodes_features_df) - num_fraud_nodes
print(f"Nodi fraudolenti: {num_fraud_nodes} ({num_fraud_nodes/len(nodes_features_df)*100:.2f}%)")
print(f"Nodi leciti:      {num_legit_nodes} ({num_legit_nodes/len(nodes_features_df)*100:.2f}%)")

num_fraud_edges = (edges_features_df["Is Laundering"] > 0).sum()
num_legit_edges = len(edges_features_df) - num_fraud_edges
print(f"Archi fraudolenti: {num_fraud_edges} ({num_fraud_edges/len(edges_features_df)*100:.2f}%)")
print(f"Archi leciti:      {num_legit_edges} ({num_legit_edges/len(edges_features_df)*100:.2f}%)")

print("\n--- Features degli archi ---")
print(list(edges_features_df.columns))

print("\n--- Features dei nodi ---")
print(list(nodes_features_df.columns))
# Out:
# Extracting time features (Unix time, Cyclic Hour, Day of Week, Week)...
# Applying edge transformation (Amounts: robust, Time: standard)...
# Aggregating node features and extracting ground truth labels...
# Dimensione feature archi: (5078345, 53)
# Dimensione feature nodi: (515080, 50)
#
# --- Bilanciamento Dataset ---
# Nodi fraudolenti: 6357 (1.23%)
# Nodi leciti:      508723 (98.77%)
# Archi fraudolenti: 5177 (0.10%)
# Archi leciti:      5073168 (99.90%)
#
# --- Features degli archi ---
# ['Amount Received', 'Amount Paid', 'Receiving Currency_Australian Dollar', 'Receiving Currency_Bitcoin', 'Receiving Currency_Brazil Real', 'Receiving Currency_Canadian Dollar', 'Receiving Currency_Euro', 'Receiving Currency_Mexican Peso', 'Receiving Currency_Ruble', 'Receiving Currency_Rupee', 'Receiving Currency_Saudi Riyal', 'Receiving Currency_Shekel', 'Receiving Currency_Swiss Franc', 'Receiving Currency_UK Pound', 'Receiving Currency_US Dollar', 'Receiving Currency_Yen', 'Receiving Currency_Yuan', 'Payment Currency_Australian Dollar', 'Payment Currency_Bitcoin', 'Payment Currency_Brazil Real', 'Payment Currency_Canadian Dollar', 'Payment Currency_Euro', 'Payment Currency_Mexican Peso', 'Payment Currency_Ruble', 'Payment Currency_Rupee', 'Payment Currency_Saudi Riyal', 'Payment Currency_Shekel', 'Payment Currency_Swiss Franc', 'Payment Currency_UK Pound', 'Payment Currency_US Dollar', 'Payment Currency_Yen', 'Payment Currency_Yuan', 'Payment Format_ACH', 'Payment Format_Bitcoin', 'Payment Format_Cash', 'Payment Format_Cheque', 'Payment Format_Credit Card', 'Payment Format_Reinvestment', 'Payment Format_Wire', 'Day_of_Week_0', 'Day_of_Week_1', 'Day_of_Week_2', 'Day_of_Week_3', 'Day_of_Week_4', 'Day_of_Week_5', 'Day_of_Week_6', 'Hour_Sin', 'Hour_Cos', 'Week', 'Account', 'Account.1', 'Is Laundering', 'Timestamp']
#
# --- Features dei nodi ---
# ['Amount Received', 'Amount Paid', 'Receiving Currency_Australian Dollar', 'Receiving Currency_Bitcoin', 'Receiving Currency_Brazil Real', 'Receiving Currency_Canadian Dollar', 'Receiving Currency_Euro', 'Receiving Currency_Mexican Peso', 'Receiving Currency_Ruble', 'Receiving Currency_Rupee', 'Receiving Currency_Saudi Riyal', 'Receiving Currency_Shekel', 'Receiving Currency_Swiss Franc', 'Receiving Currency_UK Pound', 'Receiving Currency_US Dollar', 'Receiving Currency_Yen', 'Receiving Currency_Yuan', 'Payment Currency_Australian Dollar', 'Payment Currency_Bitcoin', 'Payment Currency_Brazil Real', 'Payment Currency_Canadian Dollar', 'Payment Currency_Euro', 'Payment Currency_Mexican Peso', 'Payment Currency_Ruble', 'Payment Currency_Rupee', 'Payment Currency_Saudi Riyal', 'Payment Currency_Shekel', 'Payment Currency_Swiss Franc', 'Payment Currency_UK Pound', 'Payment Currency_US Dollar', 'Payment Currency_Yen', 'Payment Currency_Yuan', 'Payment Format_ACH', 'Payment Format_Bitcoin', 'Payment Format_Cash', 'Payment Format_Cheque', 'Payment Format_Credit Card', 'Payment Format_Reinvestment', 'Payment Format_Wire', 'Day_of_Week_0', 'Day_of_Week_1', 'Day_of_Week_2', 'Day_of_Week_3', 'Day_of_Week_4', 'Day_of_Week_5', 'Day_of_Week_6', 'Hour_Sin', 'Hour_Cos', 'Week', 'Is Laundering']

# %%
import torch
import numpy as np
import pandas as pd

print("--- Downsampling Strategy (1:1 Ratio) ---")
# 1. Identify Fraudulent and Legitimate Nodes
# A node is fraudulent if it was involved in at least one ML transaction
fraud_nodes = nodes_features_df[nodes_features_df["Is Laundering"] > 0].index
legit_nodes = nodes_features_df[nodes_features_df["Is Laundering"] == 0].index

print(f"Total Fraudulent Nodes: {len(fraud_nodes)}")
print(f"Total Legitimate Nodes (before sampling): {len(legit_nodes)}")

# 2. Sample Legitimate Nodes (1:1 ratio)
sampled_legit_nodes = pd.Series(legit_nodes).sample(n=len(fraud_nodes), random_state=42).values

# 3. Combine to form the final set of sampled users
sampled_users = set(fraud_nodes).union(set(sampled_legit_nodes))
print(f"Total Nodes after downsampling: {len(sampled_users)}")

# 4. Filter nodes_features_df and edges_features_df efficiently
nodes_features_df = nodes_features_df.loc[list(sampled_users)]

# Filter transactions: keep only those where BOTH sender and receiver are in sampled_users
edges_features_df = edges_features_df[
    edges_features_df['Account'].isin(sampled_users) & 
    edges_features_df['Account.1'].isin(sampled_users)
]

print(f"Total Edges after downsampling: {len(edges_features_df)}")

# 5. Map string Account IDs to integers (0 to N-1) for PyTorch Geometric
unique_nodes = nodes_features_df.index.unique()
node_mapping = pd.Series(index=unique_nodes, data=np.arange(len(unique_nodes)))

# 6. Extract edge_index
src = edges_features_df['Account'].map(node_mapping).values
dst = edges_features_df['Account.1'].map(node_mapping).values
edge_index = torch.tensor(np.vstack((src, dst)), dtype=torch.long)

# 7. Extract edge features and transaction labels
edge_features_cols = [c for c in edges_features_df.columns if c not in ['Account', 'Account.1', 'Is Laundering', 'Timestamp']]
edge_attr = torch.tensor(edges_features_df[edge_features_cols].values, dtype=torch.float)
y_trans = torch.tensor(edges_features_df['Is Laundering'].values, dtype=torch.float).unsqueeze(1)

# 8. Extract node features and node labels
node_features_cols = [c for c in nodes_features_df.columns if c != 'Is Laundering']
x = torch.tensor(nodes_features_df[node_features_cols].values, dtype=torch.float)

y_node = torch.tensor(nodes_features_df['Is Laundering'].values, dtype=torch.float)

print(f"Node features shape: {x.shape}")
print(f"Edge index shape: {edge_index.shape}")
print(f"Edge features shape: {edge_attr.shape}")
# Out:
# --- Downsampling Strategy (1:1 Ratio) ---
# Total Fraudulent Nodes: 6357
# Total Legitimate Nodes (before sampling): 508723
# Total Nodes after downsampling: 12714
# Total Edges after downsampling: 52250
# Node features shape: torch.Size([12714, 49])
# Edge index shape: torch.Size([2, 52250])
# Edge features shape: torch.Size([52250, 49])

# %%
import pandas as pd
from torch_geometric.data import Data

# Convert Timestamp column to datetime (use downsampled edges_features_df)
ts = pd.to_datetime(edges_features_df['Timestamp'])

# Thresholds for splits
thresh_val = pd.to_datetime(date_time_1)
thresh_test = pd.to_datetime(date_time_2)

# Create edge masks based on chronological splits
train_edge_mask = torch.tensor((ts < thresh_val).values, dtype=torch.bool)
val_edge_mask = torch.tensor(((ts >= thresh_val) & (ts < thresh_test)).values, dtype=torch.bool)
test_edge_mask = torch.tensor((ts >= thresh_test).values, dtype=torch.bool)

print(f"Train edges: {train_edge_mask.sum().item()} ({train_edge_mask.sum().item()/len(ts)*100:.1f}%)")
print(f"Val edges: {val_edge_mask.sum().item()} ({val_edge_mask.sum().item()/len(ts)*100:.1f}%)")
print(f"Test edges: {test_edge_mask.sum().item()} ({test_edge_mask.sum().item()/len(ts)*100:.1f}%)")

# Create node masks for NeighborLoader input_nodes
# A node is in the training set if it is connected to at least one training edge
train_nodes_idx = edge_index[:, train_edge_mask].flatten().unique()
train_node_mask = torch.zeros(x.shape[0], dtype=torch.bool)
train_node_mask[train_nodes_idx] = True

val_nodes_idx = edge_index[:, val_edge_mask].flatten().unique()
val_node_mask = torch.zeros(x.shape[0], dtype=torch.bool)
val_node_mask[val_nodes_idx] = True

test_nodes_idx = edge_index[:, test_edge_mask].flatten().unique()
test_node_mask = torch.zeros(x.shape[0], dtype=torch.bool)
test_node_mask[test_nodes_idx] = True

# Node mask: Using all True, as GAGNN expects a probability label for all nodes
node_mask = torch.ones(x.shape[0], dtype=torch.bool)

# Build PyG Data object
data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y_trans=y_trans, y_node=y_node)
data.node_mask = node_mask
data.edge_train_mask = train_edge_mask
data.edge_val_mask = val_edge_mask
data.edge_test_mask = test_edge_mask
data.train_node_mask = train_node_mask
data.val_node_mask = val_node_mask
data.test_node_mask = test_node_mask
# Out:
# Train edges: 38238 (73.2%)
# Val edges: 4535 (8.7%)
# Test edges: 9477 (18.1%)

# %% [markdown]
# ### Model selection

# %%
import os
import json
import itertools
from model.gagnn import GAGNN
from model.loss import GAGNNLoss
from torch_geometric.loader import NeighborLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if minibatches:
    data = data.to(device)
    train_loader = NeighborLoader(
        data, num_neighbors=num_neighbors, batch_size=batch_size,
        input_nodes=data.train_node_mask, shuffle=True
    )
    
    val_loader = NeighborLoader(
        data, num_neighbors=[-1, -1], batch_size=batch_size,
        input_nodes=data.val_node_mask, shuffle=False
    )
else:
    d_dev = data.to(device)
    train_loader = [d_dev]
    val_loader = [d_dev]

print(f"Batches per epoch (Train): {len(train_loader)} | (Val): {len(val_loader)}")

keys = ['max_norm', 'hidden_dim', 'out_dim', 'heads', 'num_layers',
        'beta', 'mlp_hidden_dim', 'nn_t_hidden_dim', 'lr',
        'c1', 'c2', 'c3', 'laundry_weight']
combinations = list(itertools.product(
    max_norm_clipping, hidden_dims, out_dims, heads_list, num_layers_list,
    betas, mlp_hidden_dims, nn_t_hidden_dims,  learning_rates,
    c1_list, c2_list, c3_list, laundry_weights
))

print(f"Total hyperparameter combinations: {len(combinations)}\n")
os.makedirs(save_to_folder, exist_ok=True)
with open(f"{save_to_folder}/configurations.txt", "w") as _f:
    _f.write(f"Total configurations tested: {len(combinations)}\n\n")
    _f.write("Hyperparameter grids:\n")
    _f.write(f"max_norm_clipping: {max_norm_clipping}\n")
    _f.write(f"hidden_dims: {hidden_dims}\n")
    _f.write(f"out_dims: {out_dims}\n")
    _f.write(f"heads_list: {heads_list}\n")
    _f.write(f"num_layers_list: {num_layers_list}\n")
    _f.write(f"betas: {betas}\n")
    _f.write(f"mlp_hidden_dims: {mlp_hidden_dims}\n")
    _f.write(f"nn_t_hidden_dims: {nn_t_hidden_dims}\n")
    _f.write(f"learning_rates: {learning_rates}\n")
    _f.write(f"c1_list: {c1_list}\n")
    _f.write(f"c2_list: {c2_list}\n")
    _f.write(f"c3_list: {c3_list}\n")
    _f.write(f"laundry_weights: {laundry_weights}\n")

from sklearn.metrics import f1_score
import numpy as np
best_val_f1 = -1.0
best_params = None

os.makedirs(save_to_folder, exist_ok=True)

for idx, combo in enumerate(combinations):
    params = dict(zip(keys, combo))
    print(f"--- Experiment {idx+1}/{len(combinations)} ---")
    print(params)
    
    model = GAGNN(
        node_in_dim=x.shape[1],
        edge_feat_dim=edge_attr.shape[1],
        hidden_dim=params['hidden_dim'],
        out_dim=params['out_dim'],
        heads=params['heads'],
        beta=params['beta'],
        mlp_hidden_dim=params['mlp_hidden_dim'],
        nn_t_hidden_dim=params['nn_t_hidden_dim'],
        minibatches=minibatches,
        gnn_type=gnn_type,
        num_layers=params['num_layers']
    ).to(device)
    
    criterion = GAGNNLoss(c1=params['c1'], c2=params['c2'], c3=params['c3'], laundry_weight=params['laundry_weight'])
    optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'])
    scaler = torch.amp.GradScaler('cuda')
    
    epochs_no_improve = 0
    best_model_val_f1 = -1.0
    
    for epoch in range(epochs_model_selection):
        model.train()
        epoch_loss = 0.0
        n_batches = 0
        
        for batch in train_loader:
            optimizer.zero_grad()
            
            with torch.amp.autocast('cuda', dtype=torch.bfloat16):
                p_node, p_trans, p_group, y_group = model(
                    batch.x, batch.edge_index, batch.edge_attr, batch.edge_index.size(1),
                    y_node=batch.y_node, y_trans=batch.y_trans, trans_mask=batch.edge_train_mask
                )
            
            if p_group.numel() > 0:
                loss, _, _, _ = criterion(
                    p_node, batch.y_node.view(-1, 1),
                    p_trans, batch.y_trans,
                    p_group, y_group,
                    node_mask=batch.node_mask,
                    trans_mask=batch.edge_train_mask
                )
                scaler.scale(loss).backward()
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=params['max_norm'])
                scaler.step(optimizer)
                scaler.update()
                epoch_loss += loss.item()
                n_batches += 1
                
        train_loss = epoch_loss / max(n_batches, 1)
        model.training_losses.append(train_loss)
        
        model.eval()
        all_preds = []
        all_labels = []
        with torch.no_grad():
            for batch in val_loader:
                with torch.amp.autocast('cuda', dtype=torch.bfloat16):
                    p_node, p_trans, p_group, y_group = model(
                        batch.x, batch.edge_index, batch.edge_attr, batch.edge_index.size(1),
                        y_trans=batch.y_trans, trans_mask=batch.edge_val_mask
                    )
                if p_group.numel() > 0:
                    p_trans_val = p_trans[batch.edge_val_mask]
                    y_trans_val = batch.y_trans[batch.edge_val_mask]
                    probs = torch.sigmoid(p_trans_val)
                    probs_flat = probs.view(-1)
                    preds = (probs_flat >= 0.5).int()
                    labels = y_trans_val.view(-1).long()
                    all_preds.append(preds)
                    all_labels.append(labels)
                    
        if len(all_preds) > 0:
            all_preds = torch.cat(all_preds).cpu().numpy()
            all_labels = torch.cat(all_labels).cpu().numpy()
            val_f1 = f1_score(all_labels, all_preds, zero_division=0)
        else:
            val_f1 = 0.0

        model.val_F1.append(val_f1)
        window_size = min(len(model.val_F1), moving_average_epochs)
        ma_val_f1 = sum(model.val_F1[-window_size:]) / window_size

        if ma_val_f1 > best_model_val_f1:
            best_model_val_f1 = ma_val_f1
            print(f"epoch {epoch+1:03d} | new best MA F1 for this configuration: {best_model_val_f1:.4f} (Raw F1: {val_f1:.4f})")
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience_selection:
            print(f"Patience triggered at epoch {epoch+1:03d} | Train Loss: {train_loss:.4f} | Val F1-score: {val_f1:.4f}")
            break
            
        if (epoch + 1) % print_every == 0:
            print(f"Epoch {epoch+1:03d} | Train Loss: {train_loss:.4f} | Val F1-score: {val_f1:.4f}")   
        
            
    print(f"Best Val F1-score for this config: {best_model_val_f1:.4f}")
    if best_model_val_f1 > best_val_f1:
        best_val_f1 = best_model_val_f1
        best_params = params
        model.save(f"{save_to_folder}/gagnn_best_model_selection.pt")
        print(">>> New Best Parameters! Model saved.")
    else:
        print(f"No improvement over best parameters. Current: {best_model_val_f1:.4f} | Best: {best_val_f1:.4f}")

print("\n=========================================")
print(f"Overall Best Val F1-score: {best_val_f1:.4f}")
print(f"Best Parameters: {best_params}")
print("=========================================")
with open(f"{save_to_folder}/best_params.json", "w") as f:
    json.dump(best_params, f, indent=4)

print("\nPlotting training history of the best model from model selection...")
best_selection_model = GAGNN.load_saved(f"{save_to_folder}/gagnn_best_model_selection.pt")
best_selection_model.plot_training_history()
# Out:
# Batches per epoch (Train): 11 | (Val): 3
# Total hyperparameter combinations: 2592
#
# --- Experiment 1/2592 ---
# {'max_norm': 5.0, 'hidden_dim': 64, 'out_dim': 64, 'heads': 3, 'num_layers': 2, 'beta': 0.44, 'mlp_hidden_dim': 128, 'nn_t_hidden_dim': 128, 'lr': 0.0001, 'c1': 0.65, 'c2': 0.65, 'c3': 0.9, 'laundry_weight': 1.0}
# epoch 001 | new best MA F1 for this configuration: 0.0272 (Raw F1: 0.0272)
# epoch 002 | new best MA F1 for this configuration: 0.1653 (Raw F1: 0.3034)
# epoch 006 | new best MA F1 for this configuration: 0.1666 (Raw F1: 0.0475)
# epoch 013 | new best MA F1 for this configuration: 0.1711 (Raw F1: 0.1726)
# epoch 014 | new best MA F1 for this configuration: 0.1766 (Raw F1: 0.1964)
# epoch 015 | new best MA F1 for this configuration: 0.1853 (Raw F1: 0.1985)
# epoch 016 | new best MA F1 for this configuration: 0.1908 (Raw F1: 0.1932)
# Epoch 020 | Train Loss: 104.2162 | Val F1-score: 0.2179
# epoch 022 | new best MA F1 for this configuration: 0.2140 (Raw F1: 0.2559)
# Epoch 040 | Train Loss: 27.5412 | Val F1-score: 0.2662
# epoch 041 | new best MA F1 for this configuration: 0.2350 (Raw F1: 0.3078)
# epoch 044 | new best MA F1 for this configuration: 0.2388 (Raw F1: 0.1849)
# Epoch 060 | Train Loss: 14.3740 | Val F1-score: 0.1859
# epoch 080 | new best MA F1 for this configuration: 0.2584 (Raw F1: 0.2467)
# Epoch 080 | Train Loss: 11.1054 | Val F1-score: 0.2467
# epoch 082 | new best MA F1 for this configuration: 0.2605 (Raw F1: 0.3121)
# epoch 088 | new best MA F1 for this configuration: 0.2620 (Raw F1: 0.3760)
# epoch 089 | new best MA F1 for this configuration: 0.2624 (Raw F1: 0.1939)
# epoch 090 | new best MA F1 for this configuration: 0.2626 (Raw F1: 0.1925)
# Epoch 100 | Train Loss: 10.4559 | Val F1-score: 0.2066
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 114
#     110                 )
#     111                 scaler.scale(loss).backward()
#     112                 scaler.unscale_(optimizer)
#     113                 torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=params['max_norm'])
# --> 114                 scaler.step(optimizer)
#     115                 scaler.update()
#     116                 epoch_loss += loss.item()
#     117                 n_batches += 1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\amp\grad_scaler.py:478, in GradScaler.step(self, optimizer, *args, **kwargs)
#     475 if len(optimizer_state["found_inf_per_device"]) == 0:
#     476     raise AssertionError("No inf checks were recorded for this optimizer.")
# --> 478 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     480 optimizer_state["stage"] = OptState.STEPPED
#     482 return retval
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\amp\grad_scaler.py:372, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     370 retval: float | None = None
#     371 if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# --> 372     retval = optimizer.step(*args, **kwargs)
#     373 return retval
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\optimizer.py:530, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     525             raise RuntimeError(
#     526                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     527             )
#     529 # pyrefly: ignore [invalid-param-spec]
# --> 530 out = func(*args, **kwargs)
#     531 self._optimizer_step_code()
#     533 # call optimizer step post hooks
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\optimizer.py:80, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      78     torch.set_grad_enabled(self.defaults["differentiable"])
#      79     torch._dynamo.graph_break()
# ---> 80     ret = func(*args, **kwargs)
#      81 finally:
#      82     torch._dynamo.graph_break()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\adam.py:248, in Adam.step(self, closure)
#     236     beta1, beta2 = group["betas"]
#     238     has_complex = self._init_group(
#     239         group,
#     240         params_with_grad,
#    (...)    245         state_steps,
#     246     )
# --> 248     adam(
#     249         params_with_grad,
#     250         grads,
#     251         exp_avgs,
#     252         exp_avg_sqs,
#     253         max_exp_avg_sqs,
#     254         state_steps,
#     255         amsgrad=group["amsgrad"],
#     256         has_complex=has_complex,
#     257         beta1=beta1,
#     258         beta2=beta2,
#     259         lr=group["lr"],
#     260         weight_decay=group["weight_decay"],
#     261         eps=group["eps"],
#     262         maximize=group["maximize"],
#     263         foreach=group["foreach"],
#     264         capturable=group["capturable"],
#     265         differentiable=group["differentiable"],
#     266         fused=group["fused"],
#     267         grad_scale=getattr(self, "grad_scale", None),
#     268         found_inf=getattr(self, "found_inf", None),
#     269         decoupled_weight_decay=group["decoupled_weight_decay"],
#     270     )
#     272 return loss
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\optimizer.py:148, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     146     return disabled_func(*args, **kwargs)
#     147 else:
# --> 148     return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\adam.py:970, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     967 else:
#     968     func = _single_tensor_adam
# --> 970 func(
#     971     params,
#     972     grads,
#     973     exp_avgs,
#     974     exp_avg_sqs,
#     975     max_exp_avg_sqs,
#     976     state_steps,
#     977     amsgrad=amsgrad,
#     978     has_complex=has_complex,
#     979     beta1=beta1,
#     980     beta2=beta2,
#     981     lr=lr,
#     982     weight_decay=weight_decay,
#     983     eps=eps,
#     984     maximize=maximize,
#     985     capturable=capturable,
#     986     differentiable=differentiable,
#     987     grad_scale=grad_scale,
#     988     found_inf=found_inf,
#     989     decoupled_weight_decay=decoupled_weight_decay,
#     990 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\adam.py:704, in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     697             device_grads = torch._foreach_add(  # type: ignore[assignment]
#     698                 device_grads, device_params, alpha=weight_decay
#     699             )
#     701 # Decay the first and second moment running average coefficient
#     702 # Use device beta1 if beta1 is a tensor to ensure all
#     703 # tensors are on the same device
# --> 704 torch._foreach_lerp_(
#     705     device_exp_avgs, device_grads, cast(float, 1 - device_beta1)
#     706 )
#     708 torch._foreach_mul_(device_exp_avg_sqs, beta2)
#     710 # Due to the strictness of the _foreach_addcmul API, we can't have a single
#     711 # tensor scalar as the scalar arg (only python number is supported there)
#     712 # as a result, separate out the value mul
#     713 # Filed https://github.com/pytorch/pytorch/issues/139795
#
# KeyboardInterrupt:

# %% [markdown]
# ### Training

# %%
import os
import json

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("\nLoading best hyperparameters for final training...")
with open(f"{save_to_folder}/best_params.json", "r") as f:
    best_params = json.load(f)

print("\nStarting final training on Train dataset with validation...")

if minibatches:
    data = data.to(device)
    final_train_loader = NeighborLoader(
        data, num_neighbors=num_neighbors, batch_size=batch_size,
        input_nodes=data.train_node_mask, shuffle=True
    )
    final_val_loader = NeighborLoader(
        data, num_neighbors=[-1, -1], batch_size=batch_size,
        input_nodes=data.val_node_mask, shuffle=False
    )
else:
    final_train_loader = [d_dev]
    final_val_loader = [d_dev]

print(f"Batches per epoch (Final Train): {len(final_train_loader)}")

# Re-initialize the model with best parameters
final_model = GAGNN(
    node_in_dim=x.shape[1],
    edge_feat_dim=edge_attr.shape[1],
    hidden_dim=best_params['hidden_dim'],
    out_dim=best_params['out_dim'],
    heads=best_params['heads'],
    beta=best_params['beta'],
    mlp_hidden_dim=best_params['mlp_hidden_dim'],
    nn_t_hidden_dim=best_params['nn_t_hidden_dim'],
    minibatches=minibatches,
    gnn_type=gnn_type,
    num_layers=best_params['num_layers']
).to(device)

final_criterion = GAGNNLoss(c1=best_params['c1'], c2=best_params['c2'], c3=best_params['c3'], laundry_weight=best_params.get('laundry_weight', 2.0))
final_optimizer = torch.optim.Adam(final_model.parameters(), lr=best_params['lr'])
scaler = torch.amp.GradScaler('cuda')

os.makedirs(save_to_folder, exist_ok=True)

best_final_val_f1 = -1.0
epochs_no_improve = 0

for epoch in range(epochs_train):
    final_model.train()
    epoch_loss = 0.0
    n_batches = 0
    
    for batch in final_train_loader:
        final_optimizer.zero_grad()
        
        with torch.amp.autocast('cuda', dtype=torch.bfloat16):
            p_node, p_trans, p_group, y_group = final_model(
                batch.x, batch.edge_index, batch.edge_attr, batch.edge_index.size(1),
                y_node=batch.y_node, y_trans=batch.y_trans, trans_mask=batch.edge_train_mask
            )
        
        if p_group.numel() > 0:
            loss, _, _, _ = final_criterion(
                p_node, batch.y_node.view(-1, 1),
                p_trans, batch.y_trans,
                p_group, y_group,
                node_mask=batch.node_mask,
                trans_mask=batch.edge_train_mask
            )
            scaler.scale(loss).backward()
            scaler.unscale_(final_optimizer)
            torch.nn.utils.clip_grad_norm_(final_model.parameters(), max_norm=best_params['max_norm'])
            scaler.step(final_optimizer)
            scaler.update()
            epoch_loss += loss.item()
            n_batches += 1
            
    train_loss = epoch_loss / max(n_batches, 1)
    final_model.training_losses.append(train_loss)
    
    # Validation step
    final_model.eval()
    all_preds = []
    all_labels = []
    evaluated_val = torch.zeros(data.num_edges, dtype=torch.bool, device=device)
    with torch.no_grad():
        for batch in final_val_loader:
            
            if hasattr(batch, 'e_id'):
                e_id = batch.e_id
                new_mask = ~evaluated_val[e_id]
                evaluated_val[e_id] = True
            else:
                new_mask = torch.ones(batch.num_edges, dtype=torch.bool, device=device)
            val_mask = new_mask & batch.edge_val_mask
            if not val_mask.any():
                continue

            with torch.amp.autocast('cuda', dtype=torch.bfloat16):
                p_node, p_trans, p_group, y_group = final_model(
                    batch.x, batch.edge_index, batch.edge_attr, batch.edge_index.size(1),
                    y_trans=batch.y_trans, trans_mask=batch.edge_val_mask
                )
            if p_group.numel() > 0:
                p_trans_val = p_trans[val_mask]
                y_trans_val = batch.y_trans[val_mask]
                probs = torch.sigmoid(p_trans_val)
                probs_flat = probs.view(-1)
                preds = (probs_flat >= 0.5).int()
                labels = y_trans_val.view(-1).long()
                all_preds.append(preds)
                all_labels.append(labels)
                
    if len(all_preds) > 0:
        all_preds = torch.cat(all_preds).cpu().numpy()
        all_labels = torch.cat(all_labels).cpu().numpy()
        val_f1 = f1_score(all_labels, all_preds, zero_division=0)
    else:
        val_f1 = 0.0
        
    final_model.val_F1.append(val_f1)
    
    if (epoch + 1) % print_every == 0:
        print(f"Train Epoch {epoch+1:03d}/{epochs_train} | Train Loss: {train_loss:.4f} | Val F1: {val_f1:.4f}")
        
    window_size = min(len(final_model.val_F1), moving_average_epochs)
    ma_val_f1 = sum(final_model.val_F1[-window_size:]) / window_size

    if ma_val_f1 > best_final_val_f1:
        best_final_val_f1 = ma_val_f1
        epochs_no_improve = 0
        final_model.save(f"{save_to_folder}/model_trained_final.pt")
    else:
        epochs_no_improve += 1
        
    if epochs_no_improve >= patience_training:
        print(f"Patience triggered at epoch {epoch+1:03d} | Train Loss: {train_loss:.4f} | Val F1-score: {val_f1:.4f}")
        break
        
    # Save model every 10 epochs
    if (epoch + 1) % save_every == 0:
        final_model.save(f"{save_to_folder}/model_trained_{epoch+1}.pt")

print("\nPlotting training history of the final trained model...")
final_model.plot_training_history()
# Out:
# Loading best hyperparameters for final training...
#
# Starting final training on Train dataset with validation...
# Batches per epoch (Final Train): 11
# Train Epoch 020/5000 | Train Loss: 2.0507 | Val F1: 0.0170
# Train Epoch 040/5000 | Train Loss: 0.7315 | Val F1: 0.0076
# Train Epoch 060/5000 | Train Loss: 0.5854 | Val F1: 0.2200
# Train Epoch 080/5000 | Train Loss: 0.4606 | Val F1: 0.3205
# Train Epoch 100/5000 | Train Loss: 0.6170 | Val F1: 0.3405
# Train Epoch 120/5000 | Train Loss: 0.6575 | Val F1: 0.1681
# Train Epoch 140/5000 | Train Loss: 1.0237 | Val F1: 0.4451
# Train Epoch 160/5000 | Train Loss: 0.5767 | Val F1: 0.3234
# Train Epoch 180/5000 | Train Loss: 0.5036 | Val F1: 0.0447
# Train Epoch 200/5000 | Train Loss: 0.4496 | Val F1: 0.1181
# Train Epoch 220/5000 | Train Loss: 0.5002 | Val F1: 0.4349
# Train Epoch 240/5000 | Train Loss: 0.4673 | Val F1: 0.5106
# Train Epoch 260/5000 | Train Loss: 0.6148 | Val F1: 0.4968
# Train Epoch 280/5000 | Train Loss: 0.5448 | Val F1: 0.5452
# Train Epoch 300/5000 | Train Loss: 0.6702 | Val F1: 0.3959
# Train Epoch 320/5000 | Train Loss: 0.4394 | Val F1: 0.5214
# Train Epoch 340/5000 | Train Loss: 0.5005 | Val F1: 0.6433
# Train Epoch 360/5000 | Train Loss: 0.5115 | Val F1: 0.4987
# Train Epoch 380/5000 | Train Loss: 0.5377 | Val F1: 0.3907
# Train Epoch 400/5000 | Train Loss: 0.4505 | Val F1: 0.5157
# Train Epoch 420/5000 | Train Loss: 0.4117 | Val F1: 0.4630
# Train Epoch 440/5000 | Train Loss: 0.5762 | Val F1: 0.5952
# Train Epoch 460/5000 | Train Loss: 0.4958 | Val F1: 0.5158
# Train Epoch 480/5000 | Train Loss: 0.5067 | Val F1: 0.5417
# Train Epoch 500/5000 | Train Loss: 0.4627 | Val F1: 0.5263
# Train Epoch 520/5000 | Train Loss: 0.4023 | Val F1: 0.5151
# Train Epoch 540/5000 | Train Loss: 0.3757 | Val F1: 0.5933
# Train Epoch 560/5000 | Train Loss: 0.3544 | Val F1: 0.5182
# Patience triggered at epoch 567 | Train Loss: 0.3988 | Val F1-score: 0.4186
#
# Plotting training history of the final trained model...

# %%
from utils import Evaluator

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("\nLoading best model for final evaluation on Test set...")
eval_model = GAGNN.load_saved(f"{save_to_folder}/model_trained_final.pt").to(device)

with open(f"{save_to_folder}/best_params.json", "r") as f:
    best_params = json.load(f)

eval_criterion = GAGNNLoss(c1=best_params['c1'], c2=best_params['c2'], c3=best_params['c3'])

if minibatches:
    test_loader = NeighborLoader(
        data, num_neighbors=[-1, -1], batch_size=batch_size,
        input_nodes=data.test_node_mask, shuffle=False
    )
    Evaluator.evaluation_report(eval_model, test_loader, eval_criterion, device, edge_mask_name='edge_test_mask')
else:
    Evaluator.evaluation_report(eval_model, [d_dev], eval_criterion, device, edge_mask_name='edge_test_mask')
# Out:
# Loading best model for final evaluation on Test set...
# ==================================================
#     EVALUATION REPORT (Transactions / Edges)
# ==================================================
#   Accuracy  : 0.9060
#   Precision : 0.7740
#   Recall    : 0.7125
#   F1-Score  : 0.7420
#   ROC-AUC   : 0.8935
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#        Legit       0.93      0.95      0.94      7679
#   Laundering       0.77      0.71      0.74      1798
#
#     accuracy                           0.91      9477
#    macro avg       0.85      0.83      0.84      9477
# weighted avg       0.90      0.91      0.90      9477

# %%
eval_model.plot_training_history()

# %% [markdown]
# ## Baseline: Standalone GAT (without GAGNN pipeline)
#
# Ablation study: trains **only the GAT backbone** — no eMRF, no
# GroupRepresentationLayer, no multi-task GAGNN loss — as a direct edge-level
# Money Laundering classifier.
#
# Edge features are fed **into GNN message passing** (native `edge_dim` support).
#
# The same `data`, `train_node_mask`, `val_node_mask`, and `test_node_mask`
# built earlier in this notebook are reused without modification.

# %%
# =============================================================================
# Baseline GAT — Hyperparameter Grid
# =============================================================================
baseline_save_to_folder = 'saved_models_GAT/baseline'

baseline_hidden_dims = [64, 128]
baseline_out_dims = [64, 128, 256]
baseline_num_layers_list = [2, 3]
baseline_mlp_hidden_dims = [64, 128, 256]
baseline_learning_rates = [0.0001]
baseline_laundry_weights = [1.0, 2.0, 3.0]
baseline_max_norm_clipping = [5.0]

baseline_heads_list = [3, 5]

baseline_epochs_model_selection = 3000
baseline_epochs_train = 6000

baseline_patience_selection = 100
baseline_moving_average_epochs = 5
moving_average_epochs = 5
baseline_patience_training  = 200

# %% [markdown]
# ### Baseline — Model Selection

# %%
import os
import json
import itertools
import numpy as np
from sklearn.metrics import f1_score
from model.standalone_gnn import StandaloneGNN, StandaloneGNNLoss
from torch_geometric.loader import NeighborLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if minibatches:
    data = data.to(device)
    baseline_train_loader = NeighborLoader(
        data, num_neighbors=num_neighbors, batch_size=batch_size,
        input_nodes=data.train_node_mask, shuffle=True
    )
    baseline_val_loader = NeighborLoader(
        data, num_neighbors=[-1, -1], batch_size=batch_size,
        input_nodes=data.val_node_mask, shuffle=False
    )
else:
    d_dev = data.to(device)
    baseline_train_loader = [d_dev]
    baseline_val_loader   = [d_dev]

print(f"Batches per epoch (Train): {len(baseline_train_loader)} | (Val): {len(baseline_val_loader)}")

keys         = ['max_norm', 'hidden_dim', 'out_dim', 'heads', 'num_layers', 'mlp_hidden_dim', 'lr', 'laundry_weight']
combinations = list(itertools.product(
    baseline_max_norm_clipping,
    baseline_hidden_dims,
    baseline_out_dims,
    baseline_heads_list,
    baseline_num_layers_list,
    baseline_mlp_hidden_dims,
    baseline_learning_rates,
    baseline_laundry_weights
))
print(f"Total baseline combinations: {len(combinations)}\n")
os.makedirs(baseline_save_to_folder, exist_ok=True)
with open(f"{baseline_save_to_folder}/configurations.txt", "w") as _f:
    _f.write(f"Total configurations tested: {len(combinations)}\n\n")
    _f.write("Hyperparameter grids:\n")
    _f.write(f"baseline_max_norm_clipping: {baseline_max_norm_clipping}\n")
    _f.write(f"baseline_hidden_dims: {baseline_hidden_dims}\n")
    _f.write(f"baseline_out_dims: {baseline_out_dims}\n")
    _f.write(f"baseline_heads_list: {baseline_heads_list}\n")
    _f.write(f"baseline_num_layers_list: {baseline_num_layers_list}\n")
    _f.write(f"baseline_mlp_hidden_dims: {baseline_mlp_hidden_dims}\n")
    _f.write(f"baseline_learning_rates: {baseline_learning_rates}\n")
    _f.write(f"baseline_laundry_weights: {baseline_laundry_weights}\n")

best_val_f1 = -1.0
best_params = None
os.makedirs(baseline_save_to_folder, exist_ok=True)

for idx, combo in enumerate(combinations):
    params = dict(zip(keys, combo))
    params['nn_t_hidden_dim'] = params['hidden_dim'] * 2
    print(f"--- Experiment {idx + 1}/{len(combinations)} ---")
    print(params)

    model = StandaloneGNN(
    node_in_dim=x.shape[1],
    edge_feat_dim=edge_attr.shape[1],
    hidden_dim=params['hidden_dim'],
    out_dim=params['out_dim'],
    heads=params['heads'],
    num_layers=params['num_layers'],
    gnn_type='gat',
    mlp_hidden_dim=params['mlp_hidden_dim'],
    minibatches=minibatches,
).to(device)

    criterion = StandaloneGNNLoss(laundry_weight=params['laundry_weight'])
    optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'])
    scaler = torch.amp.GradScaler('cuda')

    best_model_val_f1 = -1.0
    epochs_no_improve = 0

    for epoch in range(baseline_epochs_model_selection):
        model.train()
        epoch_loss = 0.0
        n_batches  = 0

        for batch in baseline_train_loader:
            optimizer.zero_grad()

            with torch.amp.autocast('cuda', dtype=torch.bfloat16):
                p_trans = model(batch.x, batch.edge_index, batch.edge_attr)
                loss = criterion(p_trans, batch.y_trans, trans_mask=batch.edge_train_mask)

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), params['max_norm'])
            scaler.step(optimizer)
            scaler.update()

            epoch_loss += loss.item()
            n_batches  += 1

        model.training_losses.append(epoch_loss / max(n_batches, 1))

        # --- Validation ---
        model.eval()
        val_preds, val_labels = [], []
        evaluated_val = torch.zeros(data.num_edges, dtype=torch.bool, device=device)
        with torch.no_grad():
            for batch in baseline_val_loader:
                if hasattr(batch, 'e_id'):
                    e_id     = batch.e_id
                    new_mask = ~evaluated_val[e_id]
                    evaluated_val[e_id] = True
                else:
                    new_mask = torch.ones(batch.num_edges, dtype=torch.bool, device=device)
                val_mask = new_mask & batch.edge_val_mask
                if not val_mask.any():
                    continue
                with torch.amp.autocast('cuda', dtype=torch.bfloat16):
                    p_trans = model(batch.x, batch.edge_index, batch.edge_attr)
                probs   = torch.sigmoid(p_trans[val_mask].float()).view(-1)
                preds   = (probs >= 0.5).int()
                labels  = batch.y_trans[val_mask].view(-1).long()
                val_preds.append(preds)
                val_labels.append(labels)

        val_f1 = (
            f1_score(torch.cat(val_labels).cpu().numpy(), torch.cat(val_preds).cpu().numpy(), zero_division=0)
            if val_preds else 0.0
        )
        model.val_F1.append(val_f1)

        window_size = min(len(model.val_F1), baseline_moving_average_epochs)
        ma_val_f1 = sum(model.val_F1[-window_size:]) / window_size

        if ma_val_f1 > best_model_val_f1:
            best_model_val_f1 = ma_val_f1
            epochs_no_improve = 0
            print(f"epoch {epoch+1:03d} | new best MA F1 for this configuration: {best_model_val_f1:.4f} (Raw F1: {val_f1:.4f})")
        else:
            epochs_no_improve += 1
            
        if (epoch + 1) % 20 == 0:
            train_loss = epoch_loss / max(n_batches, 1)
            print(f"Epoch {epoch + 1:03d} | Train Loss: {train_loss:.4f} | Val F1-score: {val_f1:.4f}")
            
        if epochs_no_improve >= baseline_patience_selection:
            print(f"  Early stopping at epoch {epoch + 1}")
            break

    print(f"  Best val F1 = {best_model_val_f1:.4f}")
    if best_model_val_f1 > best_val_f1:
        best_val_f1 = best_model_val_f1
        best_params = params
        print(f"  ** New best! Val F1 = {best_val_f1:.4f}")

print(f"\nBest baseline params : {best_params}")
print(f"Best baseline val F1 : {best_val_f1:.4f}")
with open(f"{baseline_save_to_folder}/best_baseline_params.json", "w") as f:
    json.dump(best_params, f, indent=2)
print("Saved best_baseline_params.json")
# Out:
# Batches per epoch (Train): 11 | (Val): 3
# Total baseline combinations: 324
#
# --- Experiment 1/324 ---
# {'max_norm': 5.0, 'hidden_dim': 64, 'out_dim': 64, 'heads': 3, 'num_layers': 2, 'mlp_hidden_dim': 64, 'lr': 0.0005, 'laundry_weight': 1.0, 'nn_t_hidden_dim': 128}
# epoch 001 | new best f1 for this configuration: 0.0487
# epoch 003 | new best f1 for this configuration: 0.0751
# epoch 006 | new best f1 for this configuration: 0.1613
# Epoch 020 | Train Loss: 0.3326 | Val F1-score: 0.0439
# Epoch 040 | Train Loss: 0.3320 | Val F1-score: 0.0301
# epoch 044 | new best f1 for this configuration: 0.1782
# epoch 054 | new best f1 for this configuration: 0.2539
# Epoch 060 | Train Loss: 0.2296 | Val F1-score: 0.2023
# epoch 066 | new best f1 for this configuration: 0.3215
# epoch 078 | new best f1 for this configuration: 0.3388
# Epoch 080 | Train Loss: 0.1744 | Val F1-score: 0.2694
# epoch 087 | new best f1 for this configuration: 0.3408
# epoch 090 | new best f1 for this configuration: 0.3505
# epoch 092 | new best f1 for this configuration: 0.4201
# Epoch 100 | Train Loss: 0.2775 | Val F1-score: 0.3805
# Epoch 120 | Train Loss: 0.2592 | Val F1-score: 0.4111
# epoch 132 | new best f1 for this configuration: 0.4502
# Epoch 140 | Train Loss: 0.3135 | Val F1-score: 0.4132
# epoch 141 | new best f1 for this configuration: 0.4779
# epoch 151 | new best f1 for this configuration: 0.4967
# epoch 159 | new best f1 for this configuration: 0.5231
# Epoch 160 | Train Loss: 0.1936 | Val F1-score: 0.4777
# epoch 161 | new best f1 for this configuration: 0.5561
# epoch 175 | new best f1 for this configuration: 0.5648
# Epoch 180 | Train Loss: 0.1621 | Val F1-score: 0.5342
# epoch 189 | new best f1 for this configuration: 0.5743
# epoch 191 | new best f1 for this configuration: 0.5753
# epoch 198 | new best f1 for this configuration: 0.5897
# Epoch 200 | Train Loss: 0.3150 | Val F1-score: 0.5568
# epoch 202 | new best f1 for this configuration: 0.6149
# Epoch 220 | Train Loss: 0.1612 | Val F1-score: 0.5774
# Epoch 240 | Train Loss: 0.1939 | Val F1-score: 0.5528
# Epoch 260 | Train Loss: 0.1372 | Val F1-score: 0.5831
# epoch 276 | new best f1 for this configuration: 0.6319
# Epoch 280 | Train Loss: 0.2560 | Val F1-score: 0.6051
# epoch 299 | new best f1 for this configuration: 0.6321
# Epoch 300 | Train Loss: 0.4466 | Val F1-score: 0.5925
# Epoch 320 | Train Loss: 0.1740 | Val F1-score: 0.6180
# epoch 322 | new best f1 for this configuration: 0.6322
# epoch 338 | new best f1 for this configuration: 0.6380
# Epoch 340 | Train Loss: 0.1055 | Val F1-score: 0.6238
# epoch 356 | new best f1 for this configuration: 0.6391
# epoch 357 | new best f1 for this configuration: 0.6439
# Epoch 360 | Train Loss: 0.1131 | Val F1-score: 0.6292
# epoch 365 | new best f1 for this configuration: 0.6458
# epoch 368 | new best f1 for this configuration: 0.6505
# epoch 377 | new best f1 for this configuration: 0.6509
# Epoch 380 | Train Loss: 0.1227 | Val F1-score: 0.6269
# epoch 398 | new best f1 for this configuration: 0.6537
# Epoch 400 | Train Loss: 0.1056 | Val F1-score: 0.6215
# epoch 415 | new best f1 for this configuration: 0.6575
# epoch 418 | new best f1 for this configuration: 0.6593
# Epoch 420 | Train Loss: 0.1095 | Val F1-score: 0.6256
# epoch 439 | new best f1 for this configuration: 0.6598
# Epoch 440 | Train Loss: 0.1324 | Val F1-score: 0.6376
# Epoch 460 | Train Loss: 0.1444 | Val F1-score: 0.6408
# Epoch 480 | Train Loss: 0.1713 | Val F1-score: 0.6597
# epoch 484 | new best f1 for this configuration: 0.6667
# Epoch 500 | Train Loss: 0.1977 | Val F1-score: 0.6460
# Epoch 520 | Train Loss: 0.1041 | Val F1-score: 0.6505
# epoch 530 | new best f1 for this configuration: 0.6689
# Epoch 540 | Train Loss: 0.1652 | Val F1-score: 0.6620
# epoch 551 | new best f1 for this configuration: 0.6912
# Epoch 560 | Train Loss: 0.1002 | Val F1-score: 0.6748
# Epoch 580 | Train Loss: 0.0925 | Val F1-score: 0.6596
# Epoch 600 | Train Loss: 0.1496 | Val F1-score: 0.6674
# Epoch 620 | Train Loss: 0.1472 | Val F1-score: 0.6758
# epoch 635 | new best f1 for this configuration: 0.6937
# Epoch 640 | Train Loss: 0.0902 | Val F1-score: 0.6735
# Epoch 660 | Train Loss: 0.1117 | Val F1-score: 0.6797
# epoch 668 | new best f1 for this configuration: 0.7004
# Epoch 680 | Train Loss: 0.1221 | Val F1-score: 0.6843
# epoch 682 | new best f1 for this configuration: 0.7032
# Epoch 700 | Train Loss: 0.0858 | Val F1-score: 0.6833
#   Best val F1 = 0.7032
#   ** New best! Val F1 = 0.7032
# --- Experiment 2/324 ---
# {'max_norm': 5.0, 'hidden_dim': 64, 'out_dim': 64, 'heads': 3, 'num_layers': 2, 'mlp_hidden_dim': 64, 'lr': 0.0005, 'laundry_weight': 2.0, 'nn_t_hidden_dim': 128}
# epoch 001 | new best f1 for this configuration: 0.0737
# epoch 002 | new best f1 for this configuration: 0.0933
# epoch 003 | new best f1 for this configuration: 0.2258
# epoch 009 | new best f1 for this configuration: 0.2464
# epoch 018 | new best f1 for this configuration: 0.2773
# Epoch 020 | Train Loss: 0.8108 | Val F1-score: 0.1789
# epoch 022 | new best f1 for this configuration: 0.2883
# epoch 026 | new best f1 for this configuration: 0.3031
# Epoch 040 | Train Loss: 0.6880 | Val F1-score: 0.1914
# epoch 055 | new best f1 for this configuration: 0.3086
# epoch 057 | new best f1 for this configuration: 0.3453
# Epoch 060 | Train Loss: 0.3794 | Val F1-score: 0.2827
# epoch 065 | new best f1 for this configuration: 0.3568
# epoch 071 | new best f1 for this configuration: 0.3807
# epoch 074 | new best f1 for this configuration: 0.4016
# epoch 078 | new best f1 for this configuration: 0.4084
# Epoch 080 | Train Loss: 0.4301 | Val F1-score: 0.3918
# epoch 083 | new best f1 for this configuration: 0.4191
# epoch 084 | new best f1 for this configuration: 0.4325
# epoch 091 | new best f1 for this configuration: 0.4442
# epoch 092 | new best f1 for this configuration: 0.4553
# epoch 098 | new best f1 for this configuration: 0.4617
# epoch 099 | new best f1 for this configuration: 0.4645
# epoch 100 | new best f1 for this configuration: 0.4743
# Epoch 100 | Train Loss: 0.4365 | Val F1-score: 0.4743
# epoch 104 | new best f1 for this configuration: 0.4842
# epoch 106 | new best f1 for this configuration: 0.4850
# epoch 108 | new best f1 for this configuration: 0.4970
# epoch 111 | new best f1 for this configuration: 0.5208
# epoch 118 | new best f1 for this configuration: 0.5253
# epoch 120 | new best f1 for this configuration: 0.5324
# Epoch 120 | Train Loss: 0.2651 | Val F1-score: 0.5324
# epoch 126 | new best f1 for this configuration: 0.5354
# epoch 133 | new best f1 for this configuration: 0.5511
# epoch 139 | new best f1 for this configuration: 0.5544
# Epoch 140 | Train Loss: 0.2732 | Val F1-score: 0.5542
# epoch 141 | new best f1 for this configuration: 0.5553
# epoch 144 | new best f1 for this configuration: 0.5588
# epoch 145 | new best f1 for this configuration: 0.5650
# epoch 146 | new best f1 for this configuration: 0.5841
# epoch 148 | new best f1 for this configuration: 0.5935
# Epoch 160 | Train Loss: 0.3433 | Val F1-score: 0.5751
# epoch 165 | new best f1 for this configuration: 0.5987
# epoch 167 | new best f1 for this configuration: 0.6055
# epoch 173 | new best f1 for this configuration: 0.6068
# epoch 178 | new best f1 for this configuration: 0.6227
# Epoch 180 | Train Loss: 0.2823 | Val F1-score: 0.6072
# epoch 185 | new best f1 for this configuration: 0.6235
# epoch 188 | new best f1 for this configuration: 0.6404
# Epoch 200 | Train Loss: 0.2192 | Val F1-score: 0.6232
# epoch 217 | new best f1 for this configuration: 0.6431
# epoch 219 | new best f1 for this configuration: 0.6547
# Epoch 220 | Train Loss: 0.2171 | Val F1-score: 0.6159
# Epoch 240 | Train Loss: 0.2188 | Val F1-score: 0.6351
# epoch 254 | new best f1 for this configuration: 0.6553
# Epoch 260 | Train Loss: 0.2020 | Val F1-score: 0.6430
# epoch 268 | new best f1 for this configuration: 0.6624
# epoch 271 | new best f1 for this configuration: 0.6624
# epoch 273 | new best f1 for this configuration: 0.6639
# Epoch 280 | Train Loss: 0.4846 | Val F1-score: 0.6610
# epoch 298 | new best f1 for this configuration: 0.6763
# Epoch 300 | Train Loss: 0.1873 | Val F1-score: 0.6459
# epoch 310 | new best f1 for this configuration: 0.6805
# Epoch 320 | Train Loss: 0.1980 | Val F1-score: 0.6531
# Epoch 340 | Train Loss: 0.5888 | Val F1-score: 0.6597
# Epoch 360 | Train Loss: 0.1719 | Val F1-score: 0.6574
# Epoch 380 | Train Loss: 0.2856 | Val F1-score: 0.6588
# Epoch 400 | Train Loss: 0.2144 | Val F1-score: 0.6492
#   Early stopping at epoch 410
#   Best val F1 = 0.6805
# --- Experiment 3/324 ---
# {'max_norm': 5.0, 'hidden_dim': 64, 'out_dim': 64, 'heads': 3, 'num_layers': 2, 'mlp_hidden_dim': 64, 'lr': 0.0005, 'laundry_weight': 3.0, 'nn_t_hidden_dim': 128}
# epoch 001 | new best f1 for this configuration: 0.0587
# epoch 002 | new best f1 for this configuration: 0.2497
# epoch 003 | new best f1 for this configuration: 0.2503
# Epoch 020 | Train Loss: 1.0430 | Val F1-score: 0.1623
# epoch 028 | new best f1 for this configuration: 0.2737
# epoch 031 | new best f1 for this configuration: 0.2981
# epoch 037 | new best f1 for this configuration: 0.3106
# epoch 039 | new best f1 for this configuration: 0.3725
# Epoch 040 | Train Loss: 0.6555 | Val F1-score: 0.3396
# epoch 046 | new best f1 for this configuration: 0.3818
# epoch 049 | new best f1 for this configuration: 0.3835
# epoch 053 | new best f1 for this configuration: 0.4220
# epoch 056 | new best f1 for this configuration: 0.4273
# epoch 059 | new best f1 for this configuration: 0.4356
# Epoch 060 | Train Loss: 0.7587 | Val F1-score: 0.4045
# epoch 062 | new best f1 for this configuration: 0.4609
# epoch 064 | new best f1 for this configuration: 0.4627
# epoch 069 | new best f1 for this configuration: 0.4789
# epoch 071 | new best f1 for this configuration: 0.4850
# epoch 073 | new best f1 for this configuration: 0.5118
# epoch 076 | new best f1 for this configuration: 0.5177
# epoch 079 | new best f1 for this configuration: 0.5217
# Epoch 080 | Train Loss: 0.4454 | Val F1-score: 0.5011
# epoch 081 | new best f1 for this configuration: 0.5486
# epoch 088 | new best f1 for this configuration: 0.5657
# epoch 091 | new best f1 for this configuration: 0.5745
# Epoch 100 | Train Loss: 0.4067 | Val F1-score: 0.5497
# epoch 101 | new best f1 for this configuration: 0.5874
# epoch 110 | new best f1 for this configuration: 0.6020
# epoch 114 | new best f1 for this configuration: 0.6040
# epoch 120 | new best f1 for this configuration: 0.6126
# Epoch 120 | Train Loss: 0.8702 | Val F1-score: 0.6126
# epoch 122 | new best f1 for this configuration: 0.6127
# epoch 125 | new best f1 for this configuration: 0.6254
# epoch 128 | new best f1 for this configuration: 0.6324
# epoch 131 | new best f1 for this configuration: 0.6389
# epoch 132 | new best f1 for this configuration: 0.6456
# Epoch 140 | Train Loss: 0.2849 | Val F1-score: 0.6456
# epoch 142 | new best f1 for this configuration: 0.6460
# epoch 143 | new best f1 for this configuration: 0.6500
# epoch 149 | new best f1 for this configuration: 0.6547
# epoch 151 | new best f1 for this configuration: 0.6570
# epoch 154 | new best f1 for this configuration: 0.6572
# epoch 160 | new best f1 for this configuration: 0.6591
# Epoch 160 | Train Loss: 0.4030 | Val F1-score: 0.6591
# epoch 164 | new best f1 for this configuration: 0.6605
# Epoch 180 | Train Loss: 0.6415 | Val F1-score: 0.6507
# epoch 182 | new best f1 for this configuration: 0.6641
# epoch 185 | new best f1 for this configuration: 0.6687
# epoch 190 | new best f1 for this configuration: 0.6740
# epoch 195 | new best f1 for this configuration: 0.6746
# epoch 197 | new best f1 for this configuration: 0.6829
# Epoch 200 | Train Loss: 0.3030 | Val F1-score: 0.6660
# epoch 204 | new best f1 for this configuration: 0.6867
# Epoch 220 | Train Loss: 0.2771 | Val F1-score: 0.6736
# epoch 231 | new best f1 for this configuration: 0.6928
# Epoch 240 | Train Loss: 0.4018 | Val F1-score: 0.6898
# epoch 241 | new best f1 for this configuration: 0.6942
# epoch 243 | new best f1 for this configuration: 0.6993
# Epoch 260 | Train Loss: 0.7362 | Val F1-score: 0.6867
# epoch 266 | new best f1 for this configuration: 0.7014
# Epoch 280 | Train Loss: 0.2327 | Val F1-score: 0.6816
# Epoch 300 | Train Loss: 0.4040 | Val F1-score: 0.6862
# Epoch 320 | Train Loss: 0.2120 | Val F1-score: 0.6922
# epoch 333 | new best f1 for this configuration: 0.7046
# Epoch 340 | Train Loss: 0.1952 | Val F1-score: 0.6986
# Epoch 360 | Train Loss: 0.6123 | Val F1-score: 0.6880
# epoch 370 | new best f1 for this configuration: 0.7049
# epoch 375 | new best f1 for this configuration: 0.7063
# Epoch 380 | Train Loss: 0.2379 | Val F1-score: 0.7056
# epoch 387 | new best f1 for this configuration: 0.7101
# epoch 397 | new best f1 for this configuration: 0.7107
# Epoch 400 | Train Loss: 0.9836 | Val F1-score: 0.7029
# epoch 401 | new best f1 for this configuration: 0.7117
# epoch 405 | new best f1 for this configuration: 0.7149
# epoch 418 | new best f1 for this configuration: 0.7159
# Epoch 420 | Train Loss: 0.2289 | Val F1-score: 0.7075
# epoch 438 | new best f1 for this configuration: 0.7175
# Epoch 440 | Train Loss: 0.3088 | Val F1-score: 0.7106
# Epoch 460 | Train Loss: 0.6647 | Val F1-score: 0.7125
# Epoch 480 | Train Loss: 0.3832 | Val F1-score: 0.7091
# Epoch 500 | Train Loss: 0.2039 | Val F1-score: 0.7021
# Epoch 520 | Train Loss: 0.1794 | Val F1-score: 0.7018
#   Early stopping at epoch 538
#   Best val F1 = 0.7175
#   ** New best! Val F1 = 0.7175
# --- Experiment 4/324 ---
# {'max_norm': 5.0, 'hidden_dim': 64, 'out_dim': 64, 'heads': 3, 'num_layers': 2, 'mlp_hidden_dim': 128, 'lr': 0.0005, 'laundry_weight': 1.0, 'nn_t_hidden_dim': 128}
# epoch 001 | new best f1 for this configuration: 0.1736
# epoch 014 | new best f1 for this configuration: 0.1748
# Epoch 020 | Train Loss: 0.3183 | Val F1-score: 0.0615
# Epoch 040 | Train Loss: 0.6136 | Val F1-score: 0.0370
# epoch 050 | new best f1 for this configuration: 0.1861
# epoch 057 | new best f1 for this configuration: 0.1884
# epoch 059 | new best f1 for this configuration: 0.3154
# Epoch 060 | Train Loss: 0.7158 | Val F1-score: 0.1803
# Epoch 080 | Train Loss: 0.6420 | Val F1-score: 0.2484
# epoch 089 | new best f1 for this configuration: 0.3372
# epoch 091 | new best f1 for this configuration: 0.3373
# epoch 094 | new best f1 for this configuration: 0.3434
# epoch 100 | new best f1 for this configuration: 0.3565
# Epoch 100 | Train Loss: 0.4478 | Val F1-score: 0.3565
# epoch 101 | new best f1 for this configuration: 0.3710
# epoch 103 | new best f1 for this configuration: 0.3795
# epoch 105 | new best f1 for this configuration: 0.4321
# epoch 108 | new best f1 for this configuration: 0.4394
# epoch 110 | new best f1 for this configuration: 0.4605
# Epoch 120 | Train Loss: 0.2414 | Val F1-score: 0.3774
# epoch 123 | new best f1 for this configuration: 0.4628
# epoch 127 | new best f1 for this configuration: 0.4669
# epoch 130 | new best f1 for this configuration: 0.5172
# epoch 132 | new best f1 for this configuration: 0.5262
# Epoch 140 | Train Loss: 0.2742 | Val F1-score: 0.4762
# epoch 146 | new best f1 for this configuration: 0.5396
# epoch 154 | new best f1 for this configuration: 0.5396
# epoch 160 | new best f1 for this configuration: 0.5647
# Epoch 160 | Train Loss: 0.1619 | Val F1-score: 0.5647
# Epoch 180 | Train Loss: 0.2164 | Val F1-score: 0.5276
# epoch 187 | new best f1 for this configuration: 0.5777
# Epoch 200 | Train Loss: 0.1664 | Val F1-score: 0.5375
# epoch 201 | new best f1 for this configuration: 0.5862
# epoch 203 | new best f1 for this configuration: 0.6031
# epoch 214 | new best f1 for this configuration: 0.6209
# Epoch 220 | Train Loss: 0.2308 | Val F1-score: 0.5753
# epoch 230 | new best f1 for this configuration: 0.6401
# Epoch 240 | Train Loss: 0.1736 | Val F1-score: 0.6094
# Epoch 260 | Train Loss: 0.1445 | Val F1-score: 0.6185
# Epoch 280 | Train Loss: 0.1552 | Val F1-score: 0.6032
# Epoch 300 | Train Loss: 0.4060 | Val F1-score: 0.6163
# epoch 312 | new best f1 for this configuration: 0.6452
# epoch 314 | new best f1 for this configuration: 0.6547
# Epoch 320 | Train Loss: 0.1215 | Val F1-score: 0.6229
# Epoch 340 | Train Loss: 0.2739 | Val F1-score: 0.6014
# Epoch 360 | Train Loss: 0.2962 | Val F1-score: 0.6275
# epoch 367 | new best f1 for this configuration: 0.6832
# Epoch 380 | Train Loss: 0.1104 | Val F1-score: 0.6398
# Epoch 400 | Train Loss: 0.1032 | Val F1-score: 0.6628
# Epoch 420 | Train Loss: 0.2704 | Val F1-score: 0.6339
# Epoch 440 | Train Loss: 0.1855 | Val F1-score: 0.6312
# Epoch 460 | Train Loss: 0.1187 | Val F1-score: 0.6576
#   Early stopping at epoch 467
#   Best val F1 = 0.6832
# --- Experiment 5/324 ---
# {'max_norm': 5.0, 'hidden_dim': 64, 'out_dim': 64, 'heads': 3, 'num_layers': 2, 'mlp_hidden_dim': 128, 'lr': 0.0005, 'laundry_weight': 2.0, 'nn_t_hidden_dim': 128}
# epoch 001 | new best f1 for this configuration: 0.1551
# epoch 002 | new best f1 for this configuration: 0.2473
# epoch 006 | new best f1 for this configuration: 0.2561
# epoch 020 | new best f1 for this configuration: 0.3079
# Epoch 020 | Train Loss: 0.7754 | Val F1-score: 0.3079
# epoch 029 | new best f1 for this configuration: 0.3550
# Epoch 040 | Train Loss: 0.6602 | Val F1-score: 0.2508
# epoch 047 | new best f1 for this configuration: 0.3789
# epoch 055 | new best f1 for this configuration: 0.4010
# epoch 057 | new best f1 for this configuration: 0.4811
# Epoch 060 | Train Loss: 0.3035 | Val F1-score: 0.4229
# epoch 070 | new best f1 for this configuration: 0.4823
# epoch 073 | new best f1 for this configuration: 0.4982
# Epoch 080 | Train Loss: 0.4967 | Val F1-score: 0.4923
# epoch 084 | new best f1 for this configuration: 0.4994
# epoch 085 | new best f1 for this configuration: 0.5157
# epoch 092 | new best f1 for this configuration: 0.5304
# epoch 096 | new best f1 for this configuration: 0.5342
# epoch 097 | new best f1 for this configuration: 0.5349
# epoch 098 | new best f1 for this configuration: 0.5399
# epoch 100 | new best f1 for this configuration: 0.5583
# Epoch 100 | Train Loss: 0.6921 | Val F1-score: 0.5583
# epoch 103 | new best f1 for this configuration: 0.5746
# epoch 111 | new best f1 for this configuration: 0.5746
# epoch 114 | new best f1 for this configuration: 0.5762
# epoch 116 | new best f1 for this configuration: 0.5805
# epoch 119 | new best f1 for this configuration: 0.5810
# Epoch 120 | Train Loss: 0.4030 | Val F1-score: 0.5740
# epoch 121 | new best f1 for this configuration: 0.5873
# epoch 122 | new best f1 for this configuration: 0.5993
# epoch 125 | new best f1 for this configuration: 0.6123
# epoch 134 | new best f1 for this configuration: 0.6161
# epoch 137 | new best f1 for this configuration: 0.6211
# Epoch 140 | Train Loss: 0.2745 | Val F1-score: 0.6029
# epoch 144 | new best f1 for this configuration: 0.6330
# epoch 148 | new best f1 for this configuration: 0.6353
# epoch 158 | new best f1 for this configuration: 0.6485
# Epoch 160 | Train Loss: 0.2651 | Val F1-score: 0.6097
# Epoch 180 | Train Loss: 0.8484 | Val F1-score: 0.6332
# epoch 192 | new best f1 for this configuration: 0.6500
# epoch 199 | new best f1 for this configuration: 0.6603
# Epoch 200 | Train Loss: 0.3532 | Val F1-score: 0.6566
# epoch 202 | new best f1 for this configuration: 0.6631
# Epoch 220 | Train Loss: 0.1939 | Val F1-score: 0.6571
# epoch 240 | new best f1 for this configuration: 0.6696
# Epoch 240 | Train Loss: 0.6424 | Val F1-score: 0.6696
# epoch 253 | new best f1 for this configuration: 0.6703
# epoch 259 | new best f1 for this configuration: 0.6742
# Epoch 260 | Train Loss: 0.2251 | Val F1-score: 0.6207
# epoch 265 | new best f1 for this configuration: 0.6786
# epoch 266 | new best f1 for this configuration: 0.6874
# Epoch 280 | Train Loss: 0.1846 | Val F1-score: 0.6809
# Epoch 300 | Train Loss: 0.4294 | Val F1-score: 0.6324
# epoch 301 | new best f1 for this configuration: 0.6911
# Epoch 320 | Train Loss: 0.5007 | Val F1-score: 0.6896
# epoch 329 | new best f1 for this configuration: 0.6911
# epoch 339 | new best f1 for this configuration: 0.6942
# Epoch 340 | Train Loss: 0.1900 | Val F1-score: 0.6667
# epoch 341 | new best f1 for this configuration: 0.6943
# epoch 344 | new best f1 for this configuration: 0.6948
# epoch 352 | new best f1 for this configuration: 0.6956
# Epoch 360 | Train Loss: 0.5316 | Val F1-score: 0.6923
# epoch 362 | new best f1 for this configuration: 0.6969
# epoch 363 | new best f1 for this configuration: 0.6992
# epoch 366 | new best f1 for this configuration: 0.7121
# Epoch 380 | Train Loss: 0.4423 | Val F1-score: 0.7067
# Epoch 400 | Train Loss: 0.2239 | Val F1-score: 0.6834
# Epoch 420 | Train Loss: 0.1533 | Val F1-score: 0.7019
# Epoch 440 | Train Loss: 0.1471 | Val F1-score: 0.6847
# Epoch 460 | Train Loss: 0.1395 | Val F1-score: 0.6973
#   Early stopping at epoch 466
#   Best val F1 = 0.7121
# --- Experiment 6/324 ---
# {'max_norm': 5.0, 'hidden_dim': 64, 'out_dim': 64, 'heads': 3, 'num_layers': 2, 'mlp_hidden_dim': 128, 'lr': 0.0005, 'laundry_weight': 3.0, 'nn_t_hidden_dim': 128}
# epoch 001 | new best f1 for this configuration: 0.3028
# epoch 002 | new best f1 for this configuration: 0.3200
# Epoch 020 | Train Loss: 0.8574 | Val F1-score: 0.2338
# epoch 026 | new best f1 for this configuration: 0.3413
# epoch 032 | new best f1 for this configuration: 0.3680
# epoch 035 | new best f1 for this configuration: 0.3938
# epoch 039 | new best f1 for this configuration: 0.3961
# Epoch 040 | Train Loss: 0.4663 | Val F1-score: 0.3510
# epoch 045 | new best f1 for this configuration: 0.4117
# epoch 047 | new best f1 for this configuration: 0.4143
# epoch 051 | new best f1 for this configuration: 0.4220
# epoch 052 | new best f1 for this configuration: 0.4424
# epoch 055 | new best f1 for this configuration: 0.4636
# epoch 058 | new best f1 for this configuration: 0.4732
# epoch 060 | new best f1 for this configuration: 0.4744
# Epoch 060 | Train Loss: 1.0610 | Val F1-score: 0.4744
# epoch 061 | new best f1 for this configuration: 0.4756
# epoch 062 | new best f1 for this configuration: 0.4776
# epoch 063 | new best f1 for this configuration: 0.4848
# epoch 065 | new best f1 for this configuration: 0.4911
# epoch 066 | new best f1 for this configuration: 0.5105
# epoch 068 | new best f1 for this configuration: 0.5191
# epoch 071 | new best f1 for this configuration: 0.5219
# epoch 072 | new best f1 for this configuration: 0.5505
# epoch 078 | new best f1 for this configuration: 0.5506
# Epoch 080 | Train Loss: 0.6680 | Val F1-score: 0.5482
# epoch 082 | new best f1 for this configuration: 0.5514
# epoch 083 | new best f1 for this configuration: 0.5525
# epoch 088 | new best f1 for this configuration: 0.5705
# epoch 092 | new best f1 for this configuration: 0.5714
# epoch 095 | new best f1 for this configuration: 0.6069
# Epoch 100 | Train Loss: 0.6638 | Val F1-score: 0.5825
# Epoch 120 | Train Loss: 0.3066 | Val F1-score: 0.6019
# epoch 122 | new best f1 for this configuration: 0.6196
# epoch 126 | new best f1 for this configuration: 0.6232
# epoch 132 | new best f1 for this configuration: 0.6234
# Epoch 140 | Train Loss: 1.0349 | Val F1-score: 0.6126
# epoch 141 | new best f1 for this configuration: 0.6269
# epoch 142 | new best f1 for this configuration: 0.6303
# epoch 143 | new best f1 for this configuration: 0.6310
# epoch 145 | new best f1 for this configuration: 0.6339
# epoch 146 | new best f1 for this configuration: 0.6349
# epoch 147 | new best f1 for this configuration: 0.6434
# epoch 156 | new best f1 for this configuration: 0.6435
# epoch 157 | new best f1 for this configuration: 0.6504
# Epoch 160 | Train Loss: 0.6522 | Val F1-score: 0.6393
# epoch 164 | new best f1 for this configuration: 0.6520
# epoch 176 | new best f1 for this configuration: 0.6565
# Epoch 180 | Train Loss: 0.6491 | Val F1-score: 0.6490
# Epoch 200 | Train Loss: 0.4711 | Val F1-score: 0.6529
# epoch 203 | new best f1 for this configuration: 0.6576
# epoch 213 | new best f1 for this configuration: 0.6577
# epoch 216 | new best f1 for this configuration: 0.6586
# epoch 218 | new best f1 for this configuration: 0.6598
# epoch 220 | new best f1 for this configuration: 0.6699
# Epoch 220 | Train Loss: 0.5018 | Val F1-score: 0.6699
# epoch 239 | new best f1 for this configuration: 0.6712
# Epoch 240 | Train Loss: 0.2446 | Val F1-score: 0.6445
# epoch 243 | new best f1 for this configuration: 0.6765
# Epoch 260 | Train Loss: 0.2683 | Val F1-score: 0.6660
# epoch 261 | new best f1 for this configuration: 0.6766
# epoch 264 | new best f1 for this configuration: 0.6787
# Epoch 280 | Train Loss: 0.2333 | Val F1-score: 0.6680
# epoch 283 | new best f1 for this configuration: 0.6789
# epoch 286 | new best f1 for this configuration: 0.6834
# epoch 295 | new best f1 for this configuration: 0.6854
# Epoch 300 | Train Loss: 0.9636 | Val F1-score: 0.6726
# epoch 308 | new best f1 for this configuration: 0.6877
# Epoch 320 | Train Loss: 1.1570 | Val F1-score: 0.6792
# epoch 331 | new best f1 for this configuration: 0.6918
# Epoch 340 | Train Loss: 0.5534 | Val F1-score: 0.6875
# epoch 353 | new best f1 for this configuration: 0.7063
# Epoch 360 | Train Loss: 0.3668 | Val F1-score: 0.6789
# Epoch 380 | Train Loss: 0.5091 | Val F1-score: 0.6889
# Epoch 400 | Train Loss: 0.1927 | Val F1-score: 0.6709
# Epoch 420 | Train Loss: 0.1985 | Val F1-score: 0.6785
# epoch 429 | new best f1 for this configuration: 0.7117
# Epoch 440 | Train Loss: 0.4887 | Val F1-score: 0.6834
# Epoch 460 | Train Loss: 0.2116 | Val F1-score: 0.7013
# Epoch 480 | Train Loss: 0.4760 | Val F1-score: 0.6792
# Epoch 500 | Train Loss: 0.4489 | Val F1-score: 0.6639
# epoch 511 | new best f1 for this configuration: 0.7120
# epoch 513 | new best f1 for this configuration: 0.7147
# Epoch 520 | Train Loss: 0.2643 | Val F1-score: 0.6954
# Epoch 540 | Train Loss: 0.2671 | Val F1-score: 0.7055
# Epoch 560 | Train Loss: 0.3855 | Val F1-score: 0.6814
# Epoch 580 | Train Loss: 0.2372 | Val F1-score: 0.6958
# epoch 596 | new best f1 for this configuration: 0.7154
# Epoch 600 | Train Loss: 0.4200 | Val F1-score: 0.6952
# Epoch 620 | Train Loss: 0.4199 | Val F1-score: 0.7008
# Epoch 640 | Train Loss: 0.2025 | Val F1-score: 0.6813
# epoch 641 | new best f1 for this configuration: 0.7194
# Epoch 660 | Train Loss: 0.1777 | Val F1-score: 0.6890
# epoch 673 | new best f1 for this configuration: 0.7241
# Epoch 680 | Train Loss: 0.3233 | Val F1-score: 0.6710
# Epoch 700 | Train Loss: 0.1811 | Val F1-score: 0.6950
#   Best val F1 = 0.7241
#   ** New best! Val F1 = 0.7241
# --- Experiment 7/324 ---
# {'max_norm': 5.0, 'hidden_dim': 64, 'out_dim': 64, 'heads': 3, 'num_layers': 2, 'mlp_hidden_dim': 256, 'lr': 0.0005, 'laundry_weight': 1.0, 'nn_t_hidden_dim': 128}
# epoch 001 | new best f1 for this configuration: 0.1073
# epoch 003 | new best f1 for this configuration: 0.2248
# Epoch 020 | Train Loss: 1.6596 | Val F1-score: 0.1693
# epoch 037 | new best f1 for this configuration: 0.2574
# Epoch 040 | Train Loss: 0.2648 | Val F1-score: 0.2033
# Epoch 060 | Train Loss: 0.3169 | Val F1-score: 0.1301
# epoch 062 | new best f1 for this configuration: 0.2910
# epoch 064 | new best f1 for this configuration: 0.3333
# epoch 074 | new best f1 for this configuration: 0.3476
# Epoch 080 | Train Loss: 0.6591 | Val F1-score: 0.2334
# epoch 083 | new best f1 for this configuration: 0.3678
# epoch 089 | new best f1 for this configuration: 0.3983
# epoch 095 | new best f1 for this configuration: 0.4163
# epoch 097 | new best f1 for this configuration: 0.4526
# Epoch 100 | Train Loss: 0.3852 | Val F1-score: 0.4147
# epoch 108 | new best f1 for this configuration: 0.4740
# epoch 114 | new best f1 for this configuration: 0.4994
# epoch 118 | new best f1 for this configuration: 0.5066
# epoch 120 | new best f1 for this configuration: 0.5241
# Epoch 120 | Train Loss: 0.2417 | Val F1-score: 0.5241
# epoch 130 | new best f1 for this configuration: 0.5281
# epoch 133 | new best f1 for this configuration: 0.5407
# epoch 137 | new best f1 for this configuration: 0.5414
# Epoch 140 | Train Loss: 0.3617 | Val F1-score: 0.5293
# epoch 141 | new best f1 for this configuration: 0.5443
# epoch 143 | new best f1 for this configuration: 0.5542
# epoch 145 | new best f1 for this configuration: 0.5721
# epoch 157 | new best f1 for this configuration: 0.5728
# Epoch 160 | Train Loss: 0.2423 | Val F1-score: 0.5622
# epoch 163 | new best f1 for this configuration: 0.5739
# epoch 164 | new best f1 for this configuration: 0.5885
# epoch 176 | new best f1 for this configuration: 0.5887
# Epoch 180 | Train Loss: 0.1436 | Val F1-score: 0.5756
# epoch 185 | new best f1 for this configuration: 0.6002
# epoch 190 | new best f1 for this configuration: 0.6007
# epoch 196 | new best f1 for this configuration: 0.6037
# epoch 198 | new best f1 for this configuration: 0.6064
# epoch 199 | new best f1 for this configuration: 0.6077
# Epoch 200 | Train Loss: 0.3552 | Val F1-score: 0.5957
# epoch 203 | new best f1 for this configuration: 0.6105
# epoch 206 | new best f1 for this configuration: 0.6224
# epoch 211 | new best f1 for this configuration: 0.6246
# epoch 217 | new best f1 for this configuration: 0.6343
# epoch 219 | new best f1 for this configuration: 0.6455
# Epoch 220 | Train Loss: 0.1708 | Val F1-score: 0.5711
# Epoch 240 | Train Loss: 0.2218 | Val F1-score: 0.6373
# epoch 259 | new best f1 for this configuration: 0.6472
# Epoch 260 | Train Loss: 0.1719 | Val F1-score: 0.6361
# epoch 265 | new best f1 for this configuration: 0.6555
# epoch 269 | new best f1 for this configuration: 0.6622
# epoch 275 | new best f1 for this configuration: 0.6629
# epoch 280 | new best f1 for this configuration: 0.6731
# Epoch 280 | Train Loss: 0.7133 | Val F1-score: 0.6731
# Epoch 300 | Train Loss: 0.1652 | Val F1-score: 0.6458
# Epoch 320 | Train Loss: 0.2353 | Val F1-score: 0.6508
# Epoch 340 | Train Loss: 0.2139 | Val F1-score: 0.6577
# epoch 343 | new best f1 for this configuration: 0.6776
# epoch 360 | new best f1 for this configuration: 0.6801
# Epoch 360 | Train Loss: 0.2500 | Val F1-score: 0.6801
# epoch 367 | new best f1 for this configuration: 0.6801
# Epoch 380 | Train Loss: 0.4959 | Val F1-score: 0.6778
# epoch 391 | new best f1 for this configuration: 0.6826
# Epoch 400 | Train Loss: 0.1512 | Val F1-score: 0.6800
# epoch 410 | new best f1 for this configuration: 0.6855
# Epoch 420 | Train Loss: 0.1868 | Val F1-score: 0.6801
# epoch 422 | new best f1 for this configuration: 0.6889
# epoch 423 | new best f1 for this configuration: 0.6979
# epoch 428 | new best f1 for this configuration: 0.7088
# Epoch 440 | Train Loss: 0.0899 | Val F1-score: 0.6897
# Epoch 460 | Train Loss: 0.3736 | Val F1-score: 0.6996
# Epoch 480 | Train Loss: 0.2473 | Val F1-score: 0.6781
# Epoch 500 | Train Loss: 0.1090 | Val F1-score: 0.6971
# epoch 511 | new best f1 for this configuration: 0.7113
# Epoch 520 | Train Loss: 0.4048 | Val F1-score: 0.7011
# epoch 539 | new best f1 for this configuration: 0.7115
# Epoch 540 | Train Loss: 0.1070 | Val F1-score: 0.6986
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 97
#      93
#      94             scaler.scale(loss).backward()
#      95             scaler.unscale_(optimizer)
#      96             torch.nn.utils.clip_grad_norm_(model.parameters(), params['max_norm'])
# ---> 97             scaler.step(optimizer)
#      98             scaler.update()
#      99
#     100             epoch_loss += loss.item()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\amp\grad_scaler.py:478, in GradScaler.step(self, optimizer, *args, **kwargs)
#     475 if len(optimizer_state["found_inf_per_device"]) == 0:
#     476     raise AssertionError("No inf checks were recorded for this optimizer.")
# --> 478 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     480 optimizer_state["stage"] = OptState.STEPPED
#     482 return retval
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\amp\grad_scaler.py:372, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     370 retval: float | None = None
#     371 if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# --> 372     retval = optimizer.step(*args, **kwargs)
#     373 return retval
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\optimizer.py:530, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     525             raise RuntimeError(
#     526                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     527             )
#     529 # pyrefly: ignore [invalid-param-spec]
# --> 530 out = func(*args, **kwargs)
#     531 self._optimizer_step_code()
#     533 # call optimizer step post hooks
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\optimizer.py:80, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      78     torch.set_grad_enabled(self.defaults["differentiable"])
#      79     torch._dynamo.graph_break()
# ---> 80     ret = func(*args, **kwargs)
#      81 finally:
#      82     torch._dynamo.graph_break()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\adam.py:248, in Adam.step(self, closure)
#     236     beta1, beta2 = group["betas"]
#     238     has_complex = self._init_group(
#     239         group,
#     240         params_with_grad,
#    (...)    245         state_steps,
#     246     )
# --> 248     adam(
#     249         params_with_grad,
#     250         grads,
#     251         exp_avgs,
#     252         exp_avg_sqs,
#     253         max_exp_avg_sqs,
#     254         state_steps,
#     255         amsgrad=group["amsgrad"],
#     256         has_complex=has_complex,
#     257         beta1=beta1,
#     258         beta2=beta2,
#     259         lr=group["lr"],
#     260         weight_decay=group["weight_decay"],
#     261         eps=group["eps"],
#     262         maximize=group["maximize"],
#     263         foreach=group["foreach"],
#     264         capturable=group["capturable"],
#     265         differentiable=group["differentiable"],
#     266         fused=group["fused"],
#     267         grad_scale=getattr(self, "grad_scale", None),
#     268         found_inf=getattr(self, "found_inf", None),
#     269         decoupled_weight_decay=group["decoupled_weight_decay"],
#     270     )
#     272 return loss
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\optimizer.py:148, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     146     return disabled_func(*args, **kwargs)
#     147 else:
# --> 148     return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\adam.py:970, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     967 else:
#     968     func = _single_tensor_adam
# --> 970 func(
#     971     params,
#     972     grads,
#     973     exp_avgs,
#     974     exp_avg_sqs,
#     975     max_exp_avg_sqs,
#     976     state_steps,
#     977     amsgrad=amsgrad,
#     978     has_complex=has_complex,
#     979     beta1=beta1,
#     980     beta2=beta2,
#     981     lr=lr,
#     982     weight_decay=weight_decay,
#     983     eps=eps,
#     984     maximize=maximize,
#     985     capturable=capturable,
#     986     differentiable=differentiable,
#     987     grad_scale=grad_scale,
#     988     found_inf=found_inf,
#     989     decoupled_weight_decay=decoupled_weight_decay,
#     990 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\adam.py:721, in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     718     scaled_device_grads = device_grads  # type: ignore[assignment]
#     719     value = 1 - beta2
# --> 721 torch._foreach_addcmul_(
#     722     device_exp_avg_sqs, scaled_device_grads, device_grads, value
#     723 )
#     725 # Delete the local intermediate(s) since they won't be used anymore to save on peak memory
#     726 del device_grads
#
# KeyboardInterrupt:

# %% [markdown]
# ### Baseline — Training

# %%
import os
import json
import numpy as np
from sklearn.metrics import f1_score
from model.standalone_gnn import StandaloneGNN, StandaloneGNNLoss
from torch_geometric.loader import NeighborLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("\nLoading best baseline hyperparameters...")
with open(f"{baseline_save_to_folder}/best_baseline_params.json", "r") as f:
    best_baseline_params = json.load(f)
print(best_baseline_params)

print("\nStarting baseline final training...")

if minibatches:
    data = data.to(device)
    final_train_loader = NeighborLoader(
        data, num_neighbors=num_neighbors, batch_size=batch_size,
        input_nodes=data.train_node_mask, shuffle=True
    )
    final_val_loader = NeighborLoader(
        data, num_neighbors=[-1, -1], batch_size=batch_size,
        input_nodes=data.val_node_mask, shuffle=False
    )
else:
    d_dev = data.to(device)
    final_train_loader = [d_dev]
    final_val_loader   = [d_dev]

final_model = StandaloneGNN(
    node_in_dim=x.shape[1],
    edge_feat_dim=edge_attr.shape[1],
    hidden_dim=best_baseline_params['hidden_dim'],
    out_dim=best_baseline_params['out_dim'],
    heads=best_baseline_params['heads'],
    num_layers=best_baseline_params['num_layers'],
    gnn_type='gat',
    mlp_hidden_dim=best_baseline_params['mlp_hidden_dim'],
    minibatches=minibatches,
).to(device)

final_criterion = StandaloneGNNLoss(
    laundry_weight=best_baseline_params['laundry_weight']
)
final_optimizer = torch.optim.Adam(
    final_model.parameters(), lr=best_baseline_params['lr']
)
scaler = torch.amp.GradScaler('cuda')

os.makedirs(baseline_save_to_folder, exist_ok=True)

best_final_val_f1 = -1.0
epochs_no_improve = 0

for epoch in range(baseline_epochs_train):
    final_model.train()
    epoch_loss = 0.0
    n_batches  = 0

    for batch in final_train_loader:
        final_optimizer.zero_grad()

        with torch.amp.autocast('cuda', dtype=torch.bfloat16):
                p_trans = final_model(batch.x, batch.edge_index, batch.edge_attr)
                loss = final_criterion(p_trans, batch.y_trans, trans_mask=batch.edge_train_mask)

        scaler.scale(loss).backward()
        scaler.unscale_(final_optimizer)
        torch.nn.utils.clip_grad_norm_(
            final_model.parameters(), best_baseline_params['max_norm']
        )
        scaler.step(final_optimizer)
        scaler.update()

        epoch_loss += loss.item()
        n_batches  += 1

    final_model.training_losses.append(epoch_loss / max(n_batches, 1))

    # --- Validation ---
    final_model.eval()
    val_preds, val_labels = [], []
    evaluated_val = torch.zeros(data.num_edges, dtype=torch.bool, device=device)
    with torch.no_grad():
        for batch in final_val_loader:
            if hasattr(batch, 'e_id'):
                e_id     = batch.e_id
                new_mask = ~evaluated_val[e_id]
                evaluated_val[e_id] = True
            else:
                new_mask = torch.ones(batch.num_edges, dtype=torch.bool, device=device)
            val_mask = new_mask & batch.edge_val_mask
            if not val_mask.any():
                continue
            with torch.amp.autocast('cuda', dtype=torch.bfloat16):
                    p_trans = final_model(batch.x, batch.edge_index, batch.edge_attr)
            probs   = torch.sigmoid(p_trans[val_mask].float()).view(-1)
            preds   = (probs >= 0.5).int()
            labels  = batch.y_trans[val_mask].view(-1).long()
            val_preds.append(preds)
            val_labels.append(labels)

    val_f1 = (
        f1_score(torch.cat(val_labels).cpu().numpy(), torch.cat(val_preds).cpu().numpy(), zero_division=0)
        if val_preds else 0.0
    )
    final_model.val_F1.append(val_f1)

    if epoch % print_every == 0:
        avg_loss = epoch_loss / max(n_batches, 1)
        print(f"Epoch {epoch + 1:4d} | Loss {avg_loss:.4f} | Val F1 {val_f1:.4f}")

    window_size = min(len(final_model.val_F1), moving_average_epochs)
    ma_val_f1 = sum(final_model.val_F1[-window_size:]) / window_size

    if ma_val_f1 > best_final_val_f1:
        best_final_val_f1 = ma_val_f1
        epochs_no_improve = 0
        final_model.save(f"{baseline_save_to_folder}/baseline_model_final.pt")
    else:
        epochs_no_improve += 1

    if epochs_no_improve >= baseline_patience_training:
        print(f"Early stopping at epoch {epoch + 1}")
        break

print(f"\nBest baseline val F1 (final training): {best_final_val_f1:.4f}")
print("Model saved to baseline_model_final.pt")

# %% [markdown]
# ### Baseline — Evaluation on Test Set

# %%
from model.standalone_gnn import StandaloneGNN
from utils import Evaluator
from torch_geometric.loader import NeighborLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("\nLoading best baseline model for test evaluation...")
baseline_eval_model = StandaloneGNN.load_saved(
    f"{baseline_save_to_folder}/baseline_model_final.pt"
).to(device)

if minibatches:
    baseline_test_loader = NeighborLoader(
        data, num_neighbors=[-1, -1], batch_size=batch_size,
        input_nodes=data.test_node_mask, shuffle=False
    )
    Evaluator.baseline_evaluation_report(
        baseline_eval_model, baseline_test_loader, device,
        edge_mask_name='edge_test_mask'
    )
else:
    Evaluator.baseline_evaluation_report(
        baseline_eval_model, [d_dev], device,
        edge_mask_name='edge_test_mask'
    )

# %%
baseline_eval_model.plot_training_history()
